# %% [markdown]
# esta base de datos tiene una estrucrura schema de este tipo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Atodo esto tiene un array de de struct que haremos un explode......    a posteriori

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# asi quedo el explode------- aun no perdemos ni modificamos filas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# una vez sacamos las columnas que no utilizaremos en nuestro dataset final

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Datos originales del dataset sin haber boddado ninguna fila
#
# Número total de filas: 56642
#
# Número de review distintos 52685
#
# Número de review con valores nulos: 0
#
# Número de review repetidos: 3957
#
# Número de usuarios diferentes: 24837

# %% [markdown]
# ye convertido a pandas   tengo las siguientes columnas
#
# ![image.png](attachment:image.png)

# %% [markdown]
# luego de aplicar la funcion sentimiento

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# luego de aplicar y transforma la columna posted a años y aquellas filas que no tienen datos fueron llenados por nulos y a posteriori eliminadas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Buscamos outliers a titulo informativo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                  user_id  year  cantidad_de_posteos
#
# 23068             farsel  2010                    5
#
# 15838             Hawkez  2011                   10
#
# 14333             Corber  2012                    8
#
# 9876   76561198083857294  2013                   10
#
# 6104   76561198063316459  2014                   16
#
# 17882      OfficialSenix  2015                   18

# %% [markdown]
# dataset final  para subir a render queda de la sig. Manera
#
# ![image.png](attachment:image.png)

# %% [markdown]
# grafico informativo luego de limpieza borrado resumen final del dataset
#
# ![image.png](attachment:image.png)
